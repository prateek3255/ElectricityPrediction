# %%
import pandas as pd

# %%
df = pd.read_csv('household_power_consumption.txt',sep=';')
print(df.head())
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0
# ...

# %%
df
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# 5        16/12/2006  17:29:00               3.520                 0.522
# 6        16/12/2006  17:30:00               3.702                 0.520
# 7        16/12/2006  17:31:00               3.700                 0.520
# 8        16/12/2006  17:32:00               3.668                 0.510
# 9        16/12/2006  17:33:00               3.662                 0.510
# 10       16/12/2006  17:34:00               4.448                 0.498
# 11       16/12/2006  17:35:00               5.412                 0.470
# ...

# %%
print(df.shape[1])
# Out:
# 9

# %%
pd.to_datetime(df['Date'][0]+ ' '+df['Time'][0]).timestamp()
# Out:
# 1166270040.0

# %%
pd.to_datetime(df['Date'][1]+ ' '+df['Time'][1]).timestamp()
# Out:
# 1166270100.0

# %%
df['Timestamp']=pd.to_datetime(df['Timestamp'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime (pandas\_libs\tslib.c:44294)()
#
# pandas/_libs/src/datetime.pxd in datetime._string_to_dts (pandas\_libs\tslib.c:97369)()
#
# ValueError: Month out of range in datetime string "25/12/2007 10:36:00"
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-2b4c88f54425> in <module>()
# ----> 1 df['Timestamp']=pd.to_datetime(df['Timestamp'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     507     elif isinstance(arg, ABCSeries):
#     508         from pandas import Series
# ...

# %%
df['Timestamp']
# Out:
# 0          16/12/2006 17:24:00
# 1          16/12/2006 17:25:00
# 2          16/12/2006 17:26:00
# 3          16/12/2006 17:27:00
# 4          16/12/2006 17:28:00
# 5          16/12/2006 17:29:00
# 6          16/12/2006 17:30:00
# 7          16/12/2006 17:31:00
# 8          16/12/2006 17:32:00
# 9          16/12/2006 17:33:00
# 10         16/12/2006 17:34:00
# 11         16/12/2006 17:35:00
# 12         16/12/2006 17:36:00
# 13         16/12/2006 17:37:00
# 14         16/12/2006 17:38:00
# 15         16/12/2006 17:39:00
# 16         16/12/2006 17:40:00
# 17         16/12/2006 17:41:00
# 18         16/12/2006 17:42:00
# 19         16/12/2006 17:43:00
# 20         16/12/2006 17:44:00
# 21         16/12/2006 17:45:00
# 22         16/12/2006 17:46:00
# 23         16/12/2006 17:47:00
# 24         16/12/2006 17:48:00
# 25         16/12/2006 17:49:00
# 26         16/12/2006 17:50:00
# 27         16/12/2006 17:51:00
# 28         16/12/2006 17:52:00
# 29         16/12/2006 17:53:00
# ...
